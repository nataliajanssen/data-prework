# %% [markdown]
# # Week 1

# %% [markdown]
# **1. Building Blocks for Problem Solving - Practice quiz on Sets (3 questions)**

# %% [markdown]
# ![Snip20210215_91.png](attachment:Snip20210215_91.png)

# %% [markdown]
# **2. The infinite World of Real Numbers - Practice quiz on the Number Line, including Inequalities (8 questions)**

# %% [markdown]
# ![Snip20210215_87.png](attachment:Snip20210215_87.png)

# %% [markdown]
# **3. That Jagged S Symbol - Practice quiz on Simplification Rules and Sigma Notation (6 questions)**

# %% [markdown]
# ![Snip20210215_88.png](attachment:Snip20210215_88.png)

# %% [markdown]
# **4. That Jagged S Symbol - Graded quiz on Sets, Number Line, Inequalities, Simplification, and Sigma Notation (13 questions)**

# %% [markdown]
# ![Snip20210215_89.png](attachment:Snip20210215_89.png)

# %% [markdown]
# # Week 2

# %% [markdown]
# **1. Descartes Was Really Smart - Practice quiz on the Cartesian Plane (5 questions)**

# %% [markdown]
# ![Snip20210215_92.png](attachment:Snip20210215_92.png)

# %% [markdown]
# **2. Input-Output Machines - Practice quiz on Types of Functions (6 questions)**

# %% [markdown]
# ![Snip20210215_94.png](attachment:Snip20210215_94.png)

# %% [markdown]
# **3. Input-Output Machines - Graded quiz on Cartesian Plane and Types of Function (13 questions)**

# %% [markdown]
# ![Snip20210215_95.png](attachment:Snip20210215_95.png)

# %% [markdown]
# ![Snip20210215_96.png](attachment:Snip20210215_96.png)

# %% [markdown]
# # Week 3

# %% [markdown]
# **1. This is about that derivative stuff - Practice quiz on Tangent Lines to Functions (2 questions)**

# %% [markdown]
# ![Snip20210215_99.png](attachment:Snip20210215_99.png)

# %% [markdown]
# **2. Fast Growth, Slow Growth - Practice quiz on Exponents and Logarithms (12 questions)**

# %% [markdown]
# ![Snip20210215_100.png](attachment:Snip20210215_100.png)

# %% [markdown]
# **3. Fast Growth, Slow Growth - Graded quiz on Tangent Lines to Functions, Exponents and Logarithms (13 questions)**

# %% [markdown]
# ![Snip20210215_101.png](attachment:Snip20210215_101.png)

# %% [markdown]
# ![Snip20210215_102.png](attachment:Snip20210215_102.png)

# %% [markdown]
# # Week 4

# %% [markdown]
# **1. Basic Probability Definitions - Practice quiz on Probability Concepts (9 questions)**

# %% [markdown]
# ![Snip20210215_103.png](attachment:Snip20210215_103.png)

# %% [markdown]
# **2. Problem Solving Methods - Practice quiz on Problem Solving (9 questions)**

# %% [markdown]
# ![Snip20210215_104.png](attachment:Snip20210215_104.png)

# %% [markdown]
# ![Snip20210215_105.png](attachment:Snip20210215_105.png)

# %% [markdown]
# **3. Applying Bayes Theorem and the Binomial Theorem - Practice quiz on Bayes Theorem and the Binomial Theorem (9 questions)**

# %% [markdown]
# ![Snip20210215_106.png](attachment:Snip20210215_106.png)

# %% [markdown]
# ![Snip20210215_108.png](attachment:Snip20210215_108.png)

# %% [markdown]
# **4. Applying Bayes Theorem and the Binomial Theorem. Probability (basic and Intermediate) Graded Quiz (12 questions)**

# %% [markdown]
# ![Snip20210215_111.png](attachment:Snip20210215_111.png)

# %% [markdown]
# **Course Grades**

# %% [markdown]
# ![Snip20210211_83.png](attachment:Snip20210211_83.png)
